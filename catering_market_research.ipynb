# %% [markdown]
# ## Краткое описание проекта
#
#
# <b>Цель проекта</b> - провести стартовый анализ сектора общественного питания в Москве по имеющимся открытым данным.
#
# <b>Описание данных:</b>
# Для анализа есть открытые данные о заведениях общественного питания в Москве.
#
# <b>Задачи:</b>
#  - чтение и первичный анализ данных;
#  - изучить данные заведений в разбивке по их видам;
#  - найти отличия между сетевыми и не сетевыми заведениями;
#  - изучить данные в разбивке по улицам и районам Москвы.
#
# <b>Таблица rest_data:</b>
#  - id — идентификатор объекта;
#  - object_name — название объекта общественного питания;
#  - chain — сетевой ресторан;
#  - object_type — тип объекта общественного питания;
#  - address — адрес;
#  - number — количество посадочных мест

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np
from collections import Counter
from io import BytesIO
import requests
import folium
import json

## Импортируем блок для сохранения скриншота карты, которую создает фолиум, т.к. на GitHub она иначе не отображается
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import os
from IPython.display import Image

# %% [markdown]
# ## Чтение данных

# %%
rest_data = pd.read_csv('rest_data.csv')
rest_data.head()
# Out:
#        id             object_name chain object_type  \
# 0  151635                 СМЕТАНА   нет        кафе
# 1   77874                  Родник   нет        кафе
# 2   24309         Кафе «Академия»   нет        кафе
# 3   21894              ПИЦЦЕТОРИЯ    да        кафе
# 4  119365  Кафе «Вишневая метель»   нет        кафе
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50

# %% [markdown]
# В первых строках и названиях столбцов очевидных ошибок нет.
# Необходимо привести столбцы address и object_name к нижнему регистру.

# %%
rest_data['object_name'] = rest_data['object_name'].str.lower()
rest_data['address'] = rest_data['address'].str.lower()
rest_data.head(2)
# Out:
#        id object_name chain object_type  \
# 0  151635     сметана   нет        кафе
# 1   77874      родник   нет        кафе
#
#                                              address  number
# 0         город москва, улица егора абакумова, дом 9      48
# 1  город москва, улица талалихина, дом 2/1, корпус 1      35

# %%
rest_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15366 entries, 0 to 15365
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           15366 non-null  int64
#  1   object_name  15366 non-null  object
#  2   chain        15366 non-null  object
#  3   object_type  15366 non-null  object
#  4   address      15366 non-null  object
#  5   number       15366 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 720.4+ KB

# %% [markdown]
# Пропущенных данных нет, типы данных корректны.
# Проверим наличие очевидно не корректных данных:

# %%
for column in rest_data.columns:
    print(column)
    if rest_data[column].dtype == 'object':
        print(rest_data[column].unique())
    else:
        print('min', rest_data[column].min())
        print('max', rest_data[column].max())
    print()
# Out:
# id
# min 838
# max 223439
#
# object_name
# ['сметана' 'родник' 'кафе «академия»' ... 'бар мята lounge'
#  'мята lounge октябрьская' 'кальянная «мята lounge»']
#
# chain
# ['нет' 'да']
#
# object_type
# ['кафе' 'столовая' 'закусочная' 'предприятие быстрого обслуживания'
#  'ресторан' 'кафетерий' 'буфет' 'бар' 'магазин (отдел кулинарии)']
#
# address
# ['город москва, улица егора абакумова, дом 9'
#  'город москва, улица талалихина, дом 2/1, корпус 1'
#  'город москва, абельмановская улица, дом 6' ...
#  'город москва, салтыковская улица, дом 7г'
#  'город москва, осенний бульвар, дом 9'
#  'город москва, улица новый арбат, дом 13']
#
# number
# min 0
# max 1700

# %% [markdown]
# В столбцах object_name и address слишком много уникальных значений, поэтому их рассмотрим отдельно, когда это понадобится для дальнейшего анализа.
#
# Есть слишком большие величины в количестве мест, рассмотрим их распределение более детально:

# %%
plt.figure(figsize=(13, 7))
plt.title('Количество заведений по количеству мест в них')
ax = rest_data['number'].hist(bins = 50)
ax.set_xlabel('Количество мест')
ax.set_ylabel('Заведения')
# Out:
# Text(0, 0.5, 'Заведения')

# %%
np.percentile(rest_data['number'], [95, 99])
# Out:
# array([214., 300.])

# %% [markdown]
# На графике видно, что в данных есть выбросы: всего 1% от всех заведений имеет число мест больше 300 и только 5% - выше 214 мест. Чтобы в дальнейшем подобные выбросы не искажали результаы будем рассматривать только заведение с количеством мест до 214.

# %%
rest_data = rest_data[rest_data['number'] <= 214]

# %% [markdown]
# Также необходимо проверить заведения с количеством мест равным нулю. Отдельно необходимо будет рассмотреть названия заведений (если они понадобятся в ходе анализа).

# %%
rest_data[rest_data['number'] == 0]['object_type'].unique()
# Out:
# array(['закусочная', 'предприятие быстрого обслуживания', 'столовая',
#        'кафетерий', 'кафе', 'магазин (отдел кулинарии)', 'буфет', 'бар',
#        'ресторан'], dtype=object)

# %% [markdown]
# 0 мест бывает у всех типов заведений.

# %% [markdown]
# Рассмотрим более детально на примере ресторанов:

# %%
rest_data[(rest_data['number'] == 0) &(rest_data['object_type'] == 'ресторан')]
# Out:
#            id                       object_name chain object_type  \
# 1873    79718                        макдоналдс    да    ресторан
# 4490   152298               фудмаркет. яшечкина   нет    ресторан
# 4491   152299                фудмаркет. грачева   нет    ресторан
# 4492   152305                 фудмаркет. шапиро   нет    ресторан
# 4493   152307            фудмаркет. салпагарова   нет    ресторан
# 4501   152255                 фудмаркет.швыдкой   нет    ресторан
# 4502   152222                фудмаркет.паритова   нет    ресторан
# 4503   152224             фудмаркет. рогачикова   нет    ресторан
# 4504   152216               фудмаркет. галичкин   нет    ресторан
# 6113    27193             максимальный ресторан   нет    ресторан
# 6117    89735                        макдоналдс    да    ресторан
# 8494   152879           shvilli (реторан швили)   нет    ресторан
# 8747   154514                        макдоналдс    да    ресторан
# 8751   154529                       бургер кинг    да    ресторан
# 8754   154534                               kfc    да    ресторан
# 8756   154536                   крошка картошка    да    ресторан
# 9639   167481                        макдоналдс    да    ресторан
# 10821  182757                         голдпицца   нет    ресторан
# 11602  177047              ресторан «суши make»   нет    ресторан
# 11604  177051             ресторан «хинкальная»   нет    ресторан
# 11886   96535                        макдоналдс    да    ресторан
# 12059   94219                       бургер кинг    да    ресторан
# 12068   94597                               kfc    да    ресторан
# 12125   94635                   крошка картошка    да    ресторан
# 12888  202743                        гриль хаус   нет    ресторан
# 12893  200533                    теремок-инвест   нет    ресторан
# 12894  200537                        бургер рус   нет    ресторан
# 12895  200543  вайт вотерс хоспиталити партнерс   нет    ресторан
# 12896  200567                       гришаев в.в   нет    ресторан
# 12897  200572                       гришаев в.в   нет    ресторан
# 12898  200573                     дамаскина к.а   нет    ресторан
# 12899  200576                   мартиросян м.г.   нет    ресторан
# 12900  200582                             милти    да    ресторан
# 13017  197815                              кофе   нет    ресторан
# 14613  219023               ресторан ай дабаран   нет    ресторан
# 14620  219165                            bokker   нет    ресторан
# 14622  219037                          пице хат   нет    ресторан
# 14930  223189                    porto-pomodoro   нет    ресторан
# 14967  210764                         дейли шеф   нет    ресторан
# 15068  215755                          суши сет    да    ресторан
# 15084  214843                        coffeeshop    да    ресторан
# 15105  219032                       бургер кинг    да    ресторан
# 15108  210192                       бургер кинг    да    ресторан
# 15236  219130                               kfc    да    ресторан
# 15255  218284                         marmalato    да    ресторан
#
#                                                  address  number
# 1873   город москва, поселение московский, деревня го...       0
# 4490             город москва, улица новый арбат, дом 21       0
# 4491             город москва, улица новый арбат, дом 21       0
# 4492             город москва, улица новый арбат, дом 21       0
# 4493             город москва, улица новый арбат, дом 21       0
# 4501             город москва, улица новый арбат, дом 21       0
# 4502             город москва, улица новый арбат, дом 21       0
# 4503             город москва, улица новый арбат, дом 21       0
# 4504             город москва, улица новый арбат, дом 21       0
# 6113            город москва, профсоюзная улица, дом 61а       0
# 6117            город москва, профсоюзная улица, дом 61а       0
# 8494   город москва, поселение сосенское, калужское ш...       0
# 8747             город москва, хорошёвское шоссе, дом 27       0
# 8751             город москва, хорошёвское шоссе, дом 27       0
# 8754             город москва, хорошёвское шоссе, дом 27       0
# 8756             город москва, хорошёвское шоссе, дом 27       0
# 9639   город москва, город московский, улица хабарова...       0
# 10821  город москва, карамышевская набережная, дом 56...       0
# 11602          город москва, автозаводская улица, дом 18       0
# 11604          город москва, автозаводская улица, дом 18       0
# 11886             город москва, ходынский бульвар, дом 4       0
# 12059             город москва, ходынский бульвар, дом 4       0
# 12068             город москва, ходынский бульвар, дом 4       0
# 12125             город москва, ходынский бульвар, дом 4       0
# 12888            город москва, профсоюзная улица, дом 56       0
# 12893           город москва, профсоюзная улица, дом 61а       0
# 12894           город москва, профсоюзная улица, дом 61а       0
# 12895           город москва, профсоюзная улица, дом 61а       0
# 12896           город москва, профсоюзная улица, дом 61а       0
# 12897           город москва, профсоюзная улица, дом 61а       0
# 12898           город москва, профсоюзная улица, дом 61а       0
# 12899           город москва, профсоюзная улица, дом 61а       0
# 12900           город москва, профсоюзная улица, дом 61а       0
# 13017         город москва, 1-я квесисская улица, дом 18       0
# 14613                город москва, улица вавилова, дом 3       0
# 14620                город москва, улица вавилова, дом 3       0
# 14622                город москва, улица вавилова, дом 3       0
# 14930             город москва, ходынский бульвар, дом 4       0
# 14967  город москва, город московский, улица хабарова...       0
# 15068       город москва, улица 8 марта, дом 8, корпус 1       0
# 15084         город москва, кутузовский проспект, дом 57       0
# 15105                город москва, улица вавилова, дом 3       0
# 15108  город москва, поселение московский, киевское ш...       0
# 15236                город москва, улица вавилова, дом 3       0
# 15255            город москва, хорошёвское шоссе, дом 27       0

# %% [markdown]
# Видим, что многие из них находятся в фудкортах, также рестораны без фудкорта в названии часто находятся по одниому и тому же адресу. Вероятнее всего, у этих заведений официально нет собственных мест, т.к. они используют общие места фудкорта. Поэтому не будем менять или удалять строки с нулевым количеством мест.
#
#
# Проверим наличие дубликатов:

# %%
sum(rest_data.duplicated())
# Out:
# 0

# %% [markdown]
# Дубликатов нет.
#
# <b>Вывод:</b>
#  - привели записи адресов и названий заведений к нижнему регистру.
#  - убрали из данных все заведения, где количество мест превышает 214, т.к. таких заведений всего 5% и они могут исказить результат.
#  - Вероятнее всего, нулевое количество мест - не ошибка: у закусочных мест действительно может не быть, также их может не быть у заведений, где есть общие места с другими заведениями.
#  - Дублирующиеся данные или очевидно не корректные данные отсутствовали.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Виды объектов общественного питания

# %% [markdown]
# Рассмотрим распределение объектов общественного питания по типу:

# %%
object_type_group = rest_data.groupby('object_type', as_index=False).agg({'id':'count'})
object_type_group.columns = ['object_type', 'amount']
object_type_group = object_type_group.sort_values(by = 'amount', ascending = False)
object_type_group
# Out:
#                          object_type  amount
# 3                               кафе    6058
# 7                           ресторан    2139
# 8                           столовая    2040
# 6  предприятие быстрого обслуживания    1914
# 0                                бар     849
# 1                              буфет     568
# 4                          кафетерий     398
# 2                         закусочная     359
# 5          магазин (отдел кулинарии)     273

# %% [markdown]
# Построим график:

# %%
plt.figure(figsize=(13, 7))
plt.title('Количество объектов по типам')
ax = sns.barplot(data = object_type_group, x = 'amount', y = 'object_type', palette="viridis")
ax.set_xlabel('Количество объектов')
ax.set_ylabel('Тип объекта')
ax.set_yticklabels(['кафе', 'ресторан', 'столовая',
       'предприятие\nбыстрого обслуживания', 'бар', 'буфет', 'кафетерий',
       'закусочная', 'магазин\n(отдел кулинарии)']
)
sns.despine()

# %% [markdown]
# <b>Вывод: </b>наибольшую долю всех заведений занимают кафе, их суммарное число выше двух следующих за ними категорий. На 2-ом и 3-ем местах рестораны и столовые соответственно. Меньше всего закусочных и отделов кулинарии в магазинах.

# %% [markdown]
# ### Число мест по типам заведения

# %%
plt.figure(figsize=(13, 7))
plt.title('Распределение числа мест по типам заведений')
ax = sns.violinplot(
    x = 'object_type',
    y = 'number', 
    hue = 'chain',
    split = True,
    scale = 'width',
    data = rest_data, 
    palette = "viridis"
)
ax.set_xticklabels(['кафе', 'столовая', 'закусочная',
       'предприятие\nбыстрого\nобслуживания', 'ресторан', 'кафетерий',
       'буфет', 'бар', 'магазин\n(отдел кулинарии)'])
ax.set_ylim(-0, 250)
ax.set_xlabel('Тип заведения')
ax.set_ylabel('Количество мест')
sns.despine()

# %%
rest_data.groupby('object_type')['number'].describe().sort_values(by = '50%', ascending = False)\
.style.format('{:.0f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e1d81_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >object_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1d81_level0_row0" class="row_heading level0 row0" >столовая</th>
#       <td id="T_e1d81_row0_col0" class="data row0 col0" >2040</td>
#       <td id="T_e1d81_row0_col1" class="data row0 col1" >94</td>
#       <td id="T_e1d81_row0_col2" class="data row0 col2" >57</td>
#       <td id="T_e1d81_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e1d81_row0_col4" class="data row0 col4" >45</td>
#       <td id="T_e1d81_row0_col5" class="data row0 col5" >80</td>
#       <td id="T_e1d81_row0_col6" class="data row0 col6" >140</td>
#       <td id="T_e1d81_row0_col7" class="data row0 col7" >214</td>
#     </tr>
#     <tr>
#       <th id="T_e1d81_level0_row1" class="row_heading level0 row1" >ресторан</th>
#       <td id="T_e1d81_row1_col0" class="data row1 col0" >2139</td>
#       <td id="T_e1d81_row1_col1" class="data row1 col1" >79</td>
#       <td id="T_e1d81_row1_col2" class="data row1 col2" >46</td>
#       <td id="T_e1d81_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_e1d81_row1_col4" class="data row1 col4" >45</td>
#       <td id="T_e1d81_row1_col5" class="data row1 col5" >72</td>
#       <td id="T_e1d81_row1_col6" class="data row1 col6" >100</td>
#       <td id="T_e1d81_row1_col7" class="data row1 col7" >214</td>
#     </tr>
#     <tr>
#       <th id="T_e1d81_level0_row2" class="row_heading level0 row2" >бар</th>
#       <td id="T_e1d81_row2_col0" class="data row2 col0" >849</td>
#       <td id="T_e1d81_row2_col1" class="data row2 col1" >40</td>
#       <td id="T_e1d81_row2_col2" class="data row2 col2" >31</td>
#       <td id="T_e1d81_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_e1d81_row2_col4" class="data row2 col4" >20</td>
#       <td id="T_e1d81_row2_col5" class="data row2 col5" >35</td>
#       <td id="T_e1d81_row2_col6" class="data row2 col6" >50</td>
#       <td id="T_e1d81_row2_col7" class="data row2 col7" >200</td>
#     </tr>
#     <tr>
#       <th id="T_e1d81_level0_row3" class="row_heading level0 row3" >буфет</th>
#       <td id="T_e1d81_row3_col0" class="data row3 col0" >568</td>
#       <td id="T_e1d81_row3_col1" class="data row3 col1" >45</td>
#       <td id="T_e1d81_row3_col2" class="data row3 col2" >44</td>
#       <td id="T_e1d81_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_e1d81_row3_col4" class="data row3 col4" >13</td>
#       <td id="T_e1d81_row3_col5" class="data row3 col5" >30</td>
#       <td id="T_e1d81_row3_col6" class="data row3 col6" >70</td>
#       <td id="T_e1d81_row3_col7" class="data row3 col7" >210</td>
#     </tr>
#     <tr>
#       <th id="T_e1d81_level0_row4" class="row_heading level0 row4" >кафе</th>
#       <td id="T_e1d81_row4_col0" class="data row4 col0" >6058</td>
#       <td id="T_e1d81_row4_col1" class="data row4 col1" >38</td>
#       <td id="T_e1d81_row4_col2" class="data row4 col2" >32</td>
#       <td id="T_e1d81_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_e1d81_row4_col4" class="data row4 col4" >15</td>
#       <td id="T_e1d81_row4_col5" class="data row4 col5" >30</td>
#       <td id="T_e1d81_row4_col6" class="data row4 col6" >50</td>
#       <td id="T_e1d81_row4_col7" class="data row4 col7" >202</td>
#     </tr>
#     <tr>
#       <th id="T_e1d81_level0_row5" class="row_heading level0 row5" >кафетерий</th>
#       <td id="T_e1d81_row5_col0" class="data row5 col0" >398</td>
#       <td id="T_e1d81_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_e1d81_row5_col2" class="data row5 col2" >15</td>
#       <td id="T_e1d81_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_e1d81_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_e1d81_row5_col5" class="data row5 col5" >6</td>
#       <td id="T_e1d81_row5_col6" class="data row5 col6" >12</td>
#       <td id="T_e1d81_row5_col7" class="data row5 col7" >200</td>
#     </tr>
#     <tr>
#       <th id="T_e1d81_level0_row6" class="row_heading level0 row6" >предприятие быстрого обслуживания</th>
#       <td id="T_e1d81_row6_col0" class="data row6 col0" >1914</td>
#       <td id="T_e1d81_row6_col1" class="data row6 col1" >19</td>
#       <td id="T_e1d81_row6_col2" class="data row6 col2" >31</td>
#       <td id="T_e1d81_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_e1d81_row6_col4" class="data row6 col4" >0</td>
#       <td id="T_e1d81_row6_col5" class="data row6 col5" >5</td>
#       <td id="T_e1d81_row6_col6" class="data row6 col6" >25</td>
#       <td id="T_e1d81_row6_col7" class="data row6 col7" >210</td>
#     </tr>
#     <tr>
#       <th id="T_e1d81_level0_row7" class="row_heading level0 row7" >закусочная</th>
#       <td id="T_e1d81_row7_col0" class="data row7 col0" >359</td>
#       <td id="T_e1d81_row7_col1" class="data row7 col1" >7</td>
#       <td id="T_e1d81_row7_col2" class="data row7 col2" >13</td>
#       <td id="T_e1d81_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_e1d81_row7_col4" class="data row7 col4" >0</td>
#       <td id="T_e1d81_row7_col5" class="data row7 col5" >0</td>
#       <td id="T_e1d81_row7_col6" class="data row7 col6" >10</td>
#       <td id="T_e1d81_row7_col7" class="data row7 col7" >91</td>
#     </tr>
#     <tr>
#       <th id="T_e1d81_level0_row8" class="row_heading level0 row8" >магазин (отдел кулинарии)</th>
#       <td id="T_e1d81_row8_col0" class="data row8 col0" >273</td>
#       <td id="T_e1d81_row8_col1" class="data row8 col1" >6</td>
#       <td id="T_e1d81_row8_col2" class="data row8 col2" >10</td>
#       <td id="T_e1d81_row8_col3" class="data row8 col3" >0</td>
#       <td id="T_e1d81_row8_col4" class="data row8 col4" >0</td>
#       <td id="T_e1d81_row8_col5" class="data row8 col5" >0</td>
#       <td id="T_e1d81_row8_col6" class="data row8 col6" >8</td>
#       <td id="T_e1d81_row8_col7" class="data row8 col7" >50</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <b>Выводы: </b>
#  - В среднем количество мест в столовых и ресторанах существенно выше, чем в остальных типах заведений. При этом, количество мест в столовых распределено равномерней, чем остальных, поэтому доля заведений с количеством мест выше 150 немного ниже 25%.
#  - Закусочные, кафетерии и отделы кулинарии в магазинах стандартно имеют мест меньше остальных.
#  - У закусочных, предприятий быстрого питания и отделов кулинарии сетевые заведения чаще имеют больше мест, по сравнению с не сетевыми.

# %% [markdown]
# ### Соотношение сетевых и не сетевых заведений

# %% [markdown]
# Рассмотрим соотношение количества сетевых и не сетевых заведений.

# %%
chain_group = rest_data.groupby('chain', as_index=False).agg({'id':'count'})
chain_group = chain_group.sort_values(by = 'id', ascending = False)
chain_group['share'] = chain_group['id'] / sum(chain_group['id'])
chain_group.columns = ['chain', 'amount', 'share']
chain_group.style.format({'share':'{:.2%}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_ac09f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >chain</th>
#       <th class="col_heading level0 col1" >amount</th>
#       <th class="col_heading level0 col2" >share</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac09f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ac09f_row0_col0" class="data row0 col0" >нет</td>
#       <td id="T_ac09f_row0_col1" class="data row0 col1" >11693</td>
#       <td id="T_ac09f_row0_col2" class="data row0 col2" >80.10%</td>
#     </tr>
#     <tr>
#       <th id="T_ac09f_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_ac09f_row1_col0" class="data row1 col0" >да</td>
#       <td id="T_ac09f_row1_col1" class="data row1 col1" >2905</td>
#       <td id="T_ac09f_row1_col2" class="data row1 col2" >19.90%</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(7, 7))
data = chain_group['amount']
labels = ['не сетевые', 'сетевые']
palette_color = sns.color_palette("viridis")
ax, _, autotexts = plt.pie(data,
             labels = labels,
             colors = palette_color,
             autopct='%.0f%%',
             startangle = 0
       )
plt.title('Доля сетевых заведений по типам')
for autotext in autotexts:
    autotext.set_color('white')
plt.show()

# %% [markdown]
# <b>Вывод:</b> Основная масса заведений(около 80%) не относятся к сетевым.

# %% [markdown]
# ### Сетевое распространение видов объектов общественного питания

# %% [markdown]
# Вычислим для каждого из видов заведений общественного питания долю сетевых заведений:

# %%
chain_type_group = rest_data.groupby(['object_type', 'chain'], as_index = False).agg({'id':'count'})

object_type_group['chain_share'] = object_type_group.apply(
    lambda x: max(
        chain_type_group.loc[
        (chain_type_group['object_type'] == x['object_type']) &
        (chain_type_group['chain'] == 'да'),
        'id'
    ]) / x['amount'],
    axis = 1
)

object_type_group = object_type_group.sort_values('chain_share', ascending = False)
object_type_group.style.format({'chain_share':'{:.2%}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_945e9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >object_type</th>
#       <th class="col_heading level0 col1" >amount</th>
#       <th class="col_heading level0 col2" >chain_share</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_945e9_level0_row0" class="row_heading level0 row0" >6</th>
#       <td id="T_945e9_row0_col0" class="data row0 col0" >предприятие быстрого обслуживания</td>
#       <td id="T_945e9_row0_col1" class="data row0 col1" >1914</td>
#       <td id="T_945e9_row0_col2" class="data row0 col2" >40.86%</td>
#     </tr>
#     <tr>
#       <th id="T_945e9_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_945e9_row1_col0" class="data row1 col0" >магазин (отдел кулинарии)</td>
#       <td id="T_945e9_row1_col1" class="data row1 col1" >273</td>
#       <td id="T_945e9_row1_col2" class="data row1 col2" >28.57%</td>
#     </tr>
#     <tr>
#       <th id="T_945e9_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_945e9_row2_col0" class="data row2 col0" >ресторан</td>
#       <td id="T_945e9_row2_col1" class="data row2 col1" >2139</td>
#       <td id="T_945e9_row2_col2" class="data row2 col2" >23.70%</td>
#     </tr>
#     <tr>
#       <th id="T_945e9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_945e9_row3_col0" class="data row3 col0" >кафе</td>
#       <td id="T_945e9_row3_col1" class="data row3 col1" >6058</td>
#       <td id="T_945e9_row3_col2" class="data row3 col2" >22.76%</td>
#     </tr>
#     <tr>
#       <th id="T_945e9_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_945e9_row4_col0" class="data row4 col0" >закусочная</td>
#       <td id="T_945e9_row4_col1" class="data row4 col1" >359</td>
#       <td id="T_945e9_row4_col2" class="data row4 col2" >15.60%</td>
#     </tr>
#     <tr>
#       <th id="T_945e9_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_945e9_row5_col0" class="data row5 col0" >кафетерий</td>
#       <td id="T_945e9_row5_col1" class="data row5 col1" >398</td>
#       <td id="T_945e9_row5_col2" class="data row5 col2" >13.07%</td>
#     </tr>
#     <tr>
#       <th id="T_945e9_level0_row6" class="row_heading level0 row6" >0</th>
#       <td id="T_945e9_row6_col0" class="data row6 col0" >бар</td>
#       <td id="T_945e9_row6_col1" class="data row6 col1" >849</td>
#       <td id="T_945e9_row6_col2" class="data row6 col2" >4.36%</td>
#     </tr>
#     <tr>
#       <th id="T_945e9_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_945e9_row7_col0" class="data row7 col0" >буфет</td>
#       <td id="T_945e9_row7_col1" class="data row7 col1" >568</td>
#       <td id="T_945e9_row7_col2" class="data row7 col2" >1.94%</td>
#     </tr>
#     <tr>
#       <th id="T_945e9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_945e9_row8_col0" class="data row8 col0" >столовая</td>
#       <td id="T_945e9_row8_col1" class="data row8 col1" >2040</td>
#       <td id="T_945e9_row8_col2" class="data row8 col2" >0.15%</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(13, 10))
data = object_type_group['amount']
labels = ['предприятие \nбыстрого обслуживания', 'магазин \n(отдел кулинарии)',
       'ресторан', 'кафе', 'закусочная', 'кафетерий', 'бар', 'буфет',
       'столовая']
palette_color = sns.color_palette("viridis")
ax, _, autotexsts = plt.pie(data,
             labels = labels,
             colors = palette_color,
             autopct='%.0f%%',
             labeldistance=1.1,
             rotatelabels=True,
             startangle = 330
       )
for autotext in autotexsts:
    autotext.set_color('white')
plt.title('Доля сетевых заведений по типам')
plt.show()

# %% [markdown]
# <b>Вывод: </b>максимальная доля сетевых заведений в предприятиях быстрого обслуживания (41.13%) и отделах кулинарии магазинов (28.57%). Реже всего сетевую к сетям принадлежат столовые, буфеты и бары.

# %% [markdown]
# ### Число мест в сетевых заведения

# %%
chain_rest = rest_data[rest_data['chain'] == "да"].groupby('object_name', as_index = False).agg(
    {
        'id':'count',
        'number':'median'
    }
)
chain_rest.columns = ['object_name', 'amount', 'median_seats']
chain_rest.sample(5)
# Out:
#               object_name  amount  median_seats
# 396               помидор       1          28.0
# 398        порто мальтезе       3          90.0
# 421          простые вещи       3          45.0
# 265         кафе суши wok       1           8.0
# 445  ресторан «темпл бар»       1         135.0

# %%
plt.figure(figsize=(13, 7))
ax = sns.jointplot(
    x='amount', 
    y='median_seats',
    data=chain_rest,
    kind='reg',
    color='#4CB391',
    ylim = (0, 210),
    xlim = (0, 160),
    height = 8
)
ax.fig.suptitle('Связь количества мест и количества заведений сети')
ax.ax_joint.set_xlabel('Количество заведений')
ax.ax_joint.set_ylabel('Медианное количество мест')
sns.despine()

# %% [markdown]
# Видим что есть определенная связь: крупные сети в среднем имеют около 50 мест, в то время как среди малых сетей встречаются высокие значения(около 350 мест). Есть большое количество сетей с одним заведением, что может объясняться ошибкой или наличием сетевых заведений в других городах. Чтобы убрать влияние таких не стандартных сетей, проанализируем данные без них.

# %%
chain_rest = chain_rest[chain_rest['amount'] > 1]

ax = sns.jointplot(
    x='amount', 
    y='median_seats',
    data=chain_rest,
    kind='reg',
    color='#4CB391',
    ylim = (-5, 180),
    xlim = (-1, 160),
    height = 8
)
#ax.fig.suptitle('Связь количества мест и количества заведений сети\nбез сетей с одним заведением')
ax.ax_joint.set_xlabel('Количество заведений')
ax.ax_joint.set_ylabel('Медианное количество мест')
sns.despine()

# %% [markdown]
# Результаты предыдущего графика, фактически, дублируются. Проверим полученные данные с помощью коэффициента корреляции:

# %%
chain_rest.corr().loc['median_seats', 'amount']
# Out:
# -0.10478403721002359

# %% [markdown]
# Коэффициент корреляции отрицательный, но слабый, поэтому можем считать, что явной связи между количеством заведений и средним количеством мест в них нет.

# %% [markdown]
# <b>Вывод: </b>
#
#  - Среди сетей существенно чаще встречаются сети с небольшим числом заведений, количество мест в таких сетях в основном находится в диапазоне от 0 до 100.
#  - У крупных сетей среднее количество мест обычно не больше 100. Но сетей с количеством заведений больше 20 не много, и их количество мест находится в наиболее вероятном диапозоне, в котором находится и большинство заведений малых сетей.

# %% [markdown]
# ### Улицы

# %% [markdown]
# Проанализируем улицы по количеству заведений на них.
#
#  - Посмотрим данные топ 10 улиц по количеству заведений на них;
#  - Изучим районы, в которых находятся наиболее популярные улицы;
#  - Изучим районы, в которых находятся улицы с 1 заведением;
#
#
# Посмотрим все уникальные слова в названиях улиц и частоту их встречаемости, чтобы найти слова-маячки, по которым мы сможем выделить только названия улиц.

# %%
address_list = []
for i in rest_data['address'].str.replace(',', '').str.split(' '):
    address_list.extend(i)

print(Counter(address_list))
# Out:
# Counter({'город': 14926, 'москва': 14530, 'дом': 14088, 'улица': 8597, 'строение': 4041, '1': 3905, 'корпус': 2577, '2': 1902, 'проспект': 1428, 'шоссе': 1260, '3': 1010, '4': 799, 'проезд': 735, 'бульвар': 715, 'переулок': 714, '5': 685, '6': 525, 'большая': 505, '7': 473, '8': 467, '10': 444, 'поселение': 411, '12': 401, '9': 382, 'площадь': 377, 'набережная': 368, '11': 318, 'владение': 300, '15': 291, '13': 291, 'вал': 290, '16': 267, '14': 265, '26': 256, '17': 247, '18': 241, '20': 227, 'зеленоград': 227, '19': 226, '21': 220, 'мира': 197, '22': 195, '27': 188, 'профсоюзная': 179, 'ленинградский': 170, 'арбат': 162, '24': 160, 'пресненская': 160, 'варшавское': 157, '25': 152, 'километр': 149, '1-я': 143, '32': 142, 'ленинский': 142, 'маршала': 139, 'сосенское': 139, '23': 135, 'большой': 135, 'московский': 134, 'вернадского': 128, '33': 125, '29': 122, 'деревня': 120, 'посёлок': 119, '1-й': 117, '1а': 115, 'малая': 114, 'кутузовский': 111, '28': 110, '36': 110, 'каширское': 108, '31': 106, 'академика': 105, 'ходынский': 101, 'кировоградская': 99, 'ленинградское': 98, '2-я': 96, '35': 95, 'дмитровское': 95, '30': 94, 'мичуринский': 89, 'слобода': 89, 'ленинская': 88, 'новый': 87, 'сущёвский': 85, '13а': 81, 'алтуфьевское': 80, '3а': 80, 'земляной': 79, 'покровка': 77, 'семёновская': 77, 'пятницкая': 76, '57': 75, 'вавилова': 75, 'нижняя': 75, 'ореховый': 75, '42': 75, '39': 74, 'андропова': 74, 'люблинская': 74, 'миклухо-маклая': 74, 'домовладение': 74, '40': 72, '16а': 72, 'красносельская': 72, 'тверская': 71, '5а': 71, 'мясницкая': 71, '56': 68, '3-я': 67, '2а': 67, 'парковая': 66, '34': 63, 'хорошёвское': 63, '59': 63, '14а': 63, 'автозаводская': 63, '22-й': 63, 'лесная': 62, 'дмитровка': 62, 'волгоградский': 61, '2-й': 61, '74': 61, 'открытое': 60, 'маросейка': 60, 'ярцевская': 60, 'коммунарка': 60, '211': 60, 'ярославское': 59, 'щёлковское': 57, 'троицк': 56, '51': 55, '37': 55, 'сооружение': 55, 'красная': 54, 'рязанский': 54, 'микрорайон': 54, '48': 53, '43': 53, 'измайловское': 53, 'калужское': 53, 'верхняя': 52, 'пятницкое': 52, 'мытная': 51, 'тульская': 51, 'новодмитровская': 51, 'киевское': 51, '47': 49, '38': 48, '44': 48, 'сходненская': 48, 'энтузиастов': 48, 'киевского': 48, 'вокзала': 48, 'аллея': 47, '4а': 47, 'щербинка': 47, '71': 46, 'поля': 46, 'воскресенское': 46, 'тверская-ямская': 45, 'генерала': 45, '41': 45, '2б': 45, 'усачёва': 45, 'митинская': 45, '53': 44, 'шаболовка': 44, 'таганская': 44, 'никитская': 43, 'комсомольский': 43, '3-й': 43, 'первомайская': 43, 'цветной': 43, 'адмирала': 43, 'багратионовский': 43, '52': 42, '62': 42, '58': 42, 'новоясеневский': 42, '2/1': 41, '8а': 41, 'дмитрия': 41, 'бронная': 40, 'вешняковская': 40, 'новослободская': 40, 'театральный': 40, '4/2': 39, 'шереметьевская': 39, '50': 38, 'краснопресненская': 38, 'манежная': 38, 'бирюзова': 37, 'олимпийская': 37, 'волоколамское': 36, 'малый': 36, '46': 36, 'пролетарский': 36, '6а': 36, '55': 35, '1б': 35, 'октября': 35, 'братиславская': 35, 'бауманская': 34, 'ломоносовский': 34, 'рублёвское': 34, 'декабристов': 34, 'боровское': 34, 'московской': 34, 'кольцевой': 34, 'автодороги': 34, 'рождественский': 33, 'народного': 33, 'ополчения': 33, '7-я': 33, 'петровка': 33, 'сретенка': 33, '7а': 33, 'горы': 33, '22а': 33, 'владимирская': 32, '45': 32, 'нижегородская': 32, '61а': 32, 'серпуховская': 32, '9а': 32, 'дубнинская': 31, 'кожуховская': 31, 'нагатинская': 31, 'головинское': 31, 'дербеневская': 31, 'болотниковская': 30, 'грузинская': 30, '5-я': 30, 'кронштадтский': 30, 'павелецкая': 30, 'рочдельская': 30, 'чечёрский': 30, 'авиамоторная': 29, '20а': 29, '100': 29, 'садовническая': 29, '1/2': 29, 'сокольническая': 29, 'внуковское': 29, 'комсомольская': 29, 'никольская': 29, 'территория': 29, 'бутырская': 28, '66': 28, 'зелёный': 28, 'ямского': 28, 'кузнецкий': 28, 'мост': 28, 'перерва': 28, 'кржижановского': 27, 'сущёвская': 27, 'севастопольский': 27, 'страстной': 27, 'фестивальная': 27, 'шарикоподшипниковская': 27, '54': 26 ...

# %% [markdown]
# Среди наиболее популярных слов можем выделить аналоги улиц: переулок, бульвар, площадь, набережная, шосссе, проспект, улица.

# %%
def find_street(string):
    address = string.split(',')
    for i in address:
        if any(
            substr in i 
            for substr in 
            ['переулок', 'бульвар', 'площадь', 'набережная', 'шоссе', 'проспект', 'улица', 'проезд', 'аллея']
        ):
            return i[1:]
    return 'w/o street'

rest_data['street'] = rest_data['address'].apply(find_street)
rest_data.head()
# Out:
#        id             object_name chain object_type  \
# 0  151635                 сметана   нет        кафе
# 1   77874                  родник   нет        кафе
# 2   24309         кафе «академия»   нет        кафе
# 3   21894              пиццетория    да        кафе
# 4  119365  кафе «вишневая метель»   нет        кафе
#
#                                              address  number  \
# 0         город москва, улица егора абакумова, дом 9      48
# 1  город москва, улица талалихина, дом 2/1, корпус 1      35
# 2          город москва, абельмановская улица, дом 6      95
# 3            город москва, абрамцевская улица, дом 1      40
# 4  город москва, абрамцевская улица, дом 9, корпус 1      50
#
#                   street
# 0  улица егора абакумова
# 1       улица талалихина
# 2   абельмановская улица
# 3     абрамцевская улица
# 4     абрамцевская улица

# %% [markdown]
# Рассмотрим адреса, для которых не нашлось улицы.

# %%
rest_data.loc[rest_data['street'] == 'w/o street', 'address']
# Out:
# 394               город москва, 2-й квартал капотня, дом 1
# 1044               город москва, 9-я северная линия, дом 1
# 1405            город москва, город зеленоград, корпус 401
# 1406            город москва, город зеленоград, корпус 435
# 1407            город москва, город зеленоград, корпус 436
#                                ...
# 14997    город москва, поселение десеновское, деревня в...
# 14998    город москва, поселение десеновское, деревня в...
# 15015    поселение "мосрентген", деревня дудкино, владе...
# 15184          город москва, город зеленоград, корпус 1627
# 15274    город москва, микрорайон северное чертаново, д...
# Name: address, Length: 400, dtype: object

# %% [markdown]
# Остались только адреса, которые охватывают кварталы, городки, поселения, деревни и т.д. их мы конкретизировать не будем и в дальнейшем не будем учитывать эти адреса в анализе.

# %% [markdown]
# #### Топ 10 улиц

# %% [markdown]
# Найдем топ 10 улиц по количеству заведений на них:

# %%
streets = rest_data[rest_data['street'] != 'w/o street']\
.groupby('street', as_index = False).agg({'id':'count'}).sort_values(by='id', ascending=False)
streets.columns = ['street', 'amount']
streets.head(10)
# Out:
#                       street  amount
# 1069           проспект мира     197
# 1073       профсоюзная улица     179
# 689   ленинградский проспект     168
# 1026  пресненская набережная     160
# 399         варшавское шоссе     156
# 692       ленинский проспект     141
# 1065    проспект вернадского     128
# 679     кутузовский проспект     111
# 602          каширское шоссе     108
# 1804       ходынский бульвар     101

# %% [markdown]
# Построим график:

# %%
plt.figure(figsize=(13, 9))
plt.title('Количество заведений на первой 10-ке улиц')
ax = sns.barplot(data = streets.head(10), x = 'amount', y = 'street', palette="viridis")
ax.set_xlabel('Количество заведений')
ax.set_ylabel('Улица')
sns.despine()

# %% [markdown]
# Для определения районов, к которым относятся улицы, воспользуемся внешним файлом.

# %%
spreadsheet_id = '1WPYyWbE6p9H3kA0jti_rmHNzRvvuxgQPyWkTPW11dRE'
file_name = 'https://docs.google.com/spreadsheets/d/{}/export?format=csv'.format(spreadsheet_id)
r = requests.get(file_name)
districts = pd.read_csv(BytesIO(r.content))
districts.head(2)
# Out:
#              streetname  areaid okrug               area
# 0  Выставочный переулок      17   ЦАО  Пресненский район
# 1          улица Гашека      17   ЦАО  Пресненский район

# %%
districts['streetname'] = districts['streetname'].str.lower()

streets = streets.merge(districts, how = 'left', left_on = 'street', right_on = 'streetname')
streets = streets.drop(columns = ['streetname'], axis=1)
streets.head(20)
# Out:
#                     street  amount  areaid okrug                         area
# 0            проспект мира     197    70.0  СВАО           Алексеевский район
# 1            проспект мира     197    86.0  СВАО            Ярославский Район
# 2            проспект мира     197    78.0  СВАО           Район Марьина роща
# 3            проспект мира     197    79.0  СВАО           Останкинский район
# 4            проспект мира     197    81.0  СВАО              Район Ростокино
# 5            проспект мира     197    82.0  СВАО               Район Свиблово
# 6            проспект мира     197    16.0   ЦАО              Мещанский район
# 7        профсоюзная улица     179   123.0  ЮЗАО          Академический район
# 8        профсоюзная улица     179   132.0  ЮЗАО              Район Черемушки
# 9        профсоюзная улица     179   134.0  ЮЗАО                Район Ясенево
# 10       профсоюзная улица     179   126.0  ЮЗАО               Район Коньково
# 11       профсоюзная улица     179   129.0  ЮЗАО            Обручевский район
# 12       профсоюзная улица     179   131.0  ЮЗАО            Район Теплый Стан
# 13  ленинградский проспект     168    54.0   САО               Район Аэропорт
# 14  ленинградский проспект     168    55.0   САО                Район Беговой
# 15  ленинградский проспект     168    69.0   САО            Хорошевский район
# 16  ленинградский проспект     168    66.0   САО                  Район Сокол
# 17  пресненская набережная     160    17.0   ЦАО            Пресненский район
# 18        варшавское шоссе     156   109.0   ЮАО  Район Чертаново Центральное
# 19        варшавское шоссе     156   108.0   ЮАО     Район Чертаново Северное

# %% [markdown]
# Проверим наличие улиц, для которых не нашелся район:

# %%
streets[streets['area'].isna()]
# Out:
#                           street  amount  areaid okrug area
# 122              калужское шоссе      53     NaN   NaN  NaN
# 170   улица мичуринский проспект      37     NaN   NaN  NaN
# 274   улица александры монаховой      24     NaN   NaN  NaN
# 287               улица хабарова      23     NaN   NaN  NaN
# 295           улица липовый парк      22     NaN   NaN  NaN
# ...                          ...     ...     ...   ...  ...
# 2366        ознесенский переулок       1     NaN   NaN  NaN
# 2367            огодинская улица       1     NaN   NaN  NaN
# 2385   оводаниловская набережная       1     NaN   NaN  NaN
# 2388        новобутовский проезд       1     NaN   NaN  NaN
# 2393           новорижское шоссе       1     NaN   NaN  NaN
#
# [138 rows x 5 columns]

# %% [markdown]
# Улицы с количеством заведений больше одного можно в дальнейшем не учитывать, т.к. они точно не попадают по количетсву заведений в первую десятку, а следовательно в дальнейшем анализе не будут принимать учатсия.

# %% [markdown]
# Многие улицы входят одновременно в несколько районов и чтение в виде таблицы становится затруднительным. По таблице выше нам известно, что улица с минимальным числом заведений из первых 10-ти имеет 101 заведение.
#
# Рассмотрим количество районов для каждой из первых 10 по количеству заведений улиц:

# %%
top_streets = streets.loc[streets['amount'] >= 101, ['street', 'amount']].groupby('street', as_index=False)\
.agg({'amount':'count'}).sort_values(by = 'amount', ascending=False)
top_streets
# Out:
#                    street  amount
# 0        варшавское шоссе       8
# 4      ленинский проспект       8
# 7           проспект мира       7
# 8       профсоюзная улица       6
# 6    проспект вернадского       5
# 1         каширское шоссе       4
# 3  ленинградский проспект       4
# 2    кутузовский проспект       2
# 5  пресненская набережная       1
# 9       ходынский бульвар       1

# %% [markdown]
# Варшавское шоссе, Ленинский проспект, проспект Вернадского, Каширское шоссе - улицы, которые проходят одновременно через большое количество районов, все они проходят по южной части города. Вероятнее всего, существует связь между протяженностью улицы и количеством заведений, поэтому большая часть улиц с большим числовм заведений одновременно проходит через несколько районов.
#
# Теперь рассмотрим сколько из первой десятки улиц входит в каждый из районов:

# %%
top_areas = streets.loc[streets['amount'] >= 101, ['area', 'amount']].groupby('area', as_index=False)\
.agg({'amount':'count'}).sort_values(by = 'amount', ascending=False)
top_areas
# Out:
#                                area  amount
# 2                     Донской район       2
# 3               Ломоносовский район       2
# 35                Хорошевский район       2
# 19       Район Проспект Вернадского       2
# 6                 Обручевский район       2
# 25                Район Теплый Стан       2
# 16         Район Нагатино-Садовники       2
# 26         Район Тропарево-Никулино       2
# 11                Район Гагаринский       2
# 0               Академический район       1
# 28                  Район Черемушки       1
# 24                      Район Сокол       1
# 27             Район Фили-Давыдково       1
# 30      Район Чертаново Центральное       1
# 29         Район Чертаново Северное       1
# 22                   Район Свиблово       1
# 31            Район Чертаново Южное       1
# 32               Район Южное Бутово       1
# 33                   Район Якиманка       1
# 34                    Район Ясенево       1
# 23            Район Северное Бутово       1
# 18     Район Орехово-Борисово Южное       1
# 21                  Район Ростокино       1
# 20                    Район Раменки       1
# 1                Алексеевский район       1
# 17  Район Орехово-Борисово Северное       1
# 15       Район Москворечье-Сабурово       1
# 14               Район Марьина роща       1
# 13                   Район Коньково       1
# 12               Район Дорогомилово       1
# 10                    Район Беговой       1
# 9                    Район Аэропорт       1
# 8                 Пресненский район       1
# 7                Останкинский район       1
# 5                    Нагорный район       1
# 4                   Мещанский район       1
# 36                Ярославский Район       1

# %% [markdown]
# Отобразим полученные значения на карте для большей наглядности:

# %%
#Читаем json файл, в котором заданы границы районов Москвы
communities_geo = r'moscow.geojson'
with open(communities_geo, 'r', encoding = 'utf-8') as communities_file:
    communities_json = json.load(communities_file)

#Выводим список названий всех полученных районов
denominations_json = []
for index in range(len(communities_json['features'])):
    denominations_json.append(communities_json['features'][index]['properties']['name'])
", ".join(denominations_json)
# Out:
# 'район Восточный, Обручевский район, район Свиблово, район Зюзино, Алексеевский район, район Чертаново Центральное, район Бирюлево Западное, Басманный район, Район Матушкино-Савелки, район Силино, район Старое Крюково, район Ивановское, район Измайлово, район Гольяново, район Метрогородок, район Богородское, район Преображенское, район Соколиная Гора, район Перово, район Вешняки, район Очаково-Матвеевское, район Тропарево-Никулино, район Проспект Вернадского, район Котловка, район Чертаново Северное, Академический район, район Нагатино-Садовники, Даниловский район, Южнопортовый район, район Текстильщики, район Лефортово, Нижегородский район, район Якиманка, Таганский район, Пресненский район, Тверской район, район Арбат, Можайский район, район Северное Бутово, Красносельский район, район Хамовники, район Замоскворечье, район Косино-Ухтомский, Бабушкинский район, район Марьина Роща, район Марфино, Останкинский район, район Коньково, район Теплый Стан, Алтуфьевский район, район Ясенево, район Чертаново Южное, район Аэропорт, район Бирюлево Восточное, район Выхино-Жулебино, Нагорный район, район Братеево, район Орехово-Борисово Южное, район Орехово-Борисово Северное, район Москворечье-Сабурово, район Нагатинский Затон, район Печатники, район Марьино, район Капотня, район Люблино, Савеловский район, район Сокол, район Крюково, район Куркино, район Митино, район Хорошево-Мневники, район Сокольники, район Кунцево, район Новогиреево, Лосиноостровский район, Головинский район, Тимирязевский район, район Восточное Дегунино, район Северный, район Ховрино, Ломоносовский район, Район Гагаринский, район Восточное Измайлово, район Северное Измайлово, Бутырский район, район Новокосино, район Крылатское, район Ростокино, район Зябликово, район Филевский Парк, район Царицыно, район Некрасовка, Рязанский район, Войковский район, район Черемушки, район Савёлки, район Внуково, район Южное Бутово, Ярославский район, район Ново-Переделкино, район Солнцево, район Раменки, район Дорогомилово, район Фили-Давыдково, район Южное Медведково, район Северное Медведково, район Бибирево, район Лианозово, Бескудниковский район, район Покровское-Стрешнево, район Южное Тушино, Хорошевский район, район Беговой, район Коптево, Молжаниновский район, район Отрадное, район Северное Тушино, Дмитровский район, район Западное Дегунино, район Левобережный, Донской район, район Кузьминки, район Строгино, район Щукино, Мещанский район'

# %% [markdown]
# Проверим совпадения названий районов в json файле с ранее полученными названиями районов:

# %%
test = []
def match_areas(i):
    for z in denominations_json:
        if z.lower() == i.lower():
            return z
    test.append(i)
    return i
streets['area'] = streets['area'].dropna().apply(match_areas)
set(test)
# Out:
# {'Панфиловский район'}

# %% [markdown]
# В исходной таблице streets название Панфиловского района не совпадает, т.к. было указано устаревшее название района, который сейчас разделен на район Силино и район Старое Крюково.

# %%
streets[streets['okrug'] == 'Зеленоград']['area'].unique()
# Out:
# array(['Район Матушкино-Савелки', 'район Крюково', 'Панфиловский район'],
#       dtype=object)

# %%
streets[streets['area'] == 'Панфиловский район']
# Out:
#                      street  amount  areaid       okrug                area
# 477   железнодорожная улица      12    53.0  Зеленоград  Панфиловский район
# 496      крюковская площадь      12    53.0  Зеленоград  Панфиловский район
# 667   панфиловский проспект       9    53.0  Зеленоград  Панфиловский район
# 802         улица панфилова       7    53.0  Зеленоград  Панфиловский район
# 888         солнечная улица       6    53.0  Зеленоград  Панфиловский район
# 898          вишнёвая улица       6    53.0  Зеленоград  Панфиловский район
# 985           рабочая улица       5    53.0  Зеленоград  Панфиловский район
# 1078           улица гоголя       4    53.0  Зеленоград  Панфиловский район
# 1734           дачная улица       2    53.0  Зеленоград  Панфиловский район
# 1867   центральный проспект       1    53.0  Зеленоград  Панфиловский район
# 2167        солнечная аллея       1    53.0  Зеленоград  Панфиловский район

# %% [markdown]
# Улицы, с количеством заведений больше 1 и меньше 101 в дальнейшем анализе задействованы не будут, поэтому для них оставим Панфиловсиий район. Для Центрального проспекта заменим район на Район Матушкино-Савелки, а для Солнечной аллеи - на район Старое Крюково.

# %%
streets.loc[
    (streets['street'] == 'центральный проспект')&(streets['area'] == 'Панфиловский район'),
    'area'
] = 'Район Матушкино-Савелки'
streets.loc[
    (streets['street'] == 'солнечная аллея')&(streets['area'] == 'Панфиловский район'),
    'area'
] = 'район Старое Крюково'

# %% [markdown]
# Проверим так же названия районов из таблицы top_areas:

# %%
test = []
top_areas['area'] = top_areas['area'].apply(match_areas)
test
# Out:
# []

# %% [markdown]
# Выведем данные top_areas на карте:

# %%
communities_map = folium.Map(location=[55.7522, 37.6156], zoom_start=9, 
                              tiles='https://{s}.tile.openstreetmap.se/hydda/full/{z}/{x}/{y}.png',
                             attr="Hydda.Full"
                            )

folium.Choropleth(
    geo_data=communities_json,
    data=top_areas,
    columns=['area', 'amount'],
    key_on='feature.properties.name',
    bins = 3,
    nan_fill_color = 'white',
    fill_color='YlGnBu', 
    fill_opacity=1, 
    line_opacity=1,
    legend_name='Количество улиц из топ 10',
    smooth_factor=0).add_to(communities_map)

communities_map.save("map.html")

# %%
mapUrl = 'file://{0}/{1}'.format(os.getcwd(), 'map.html')
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(mapUrl)
l = driver.find_element(By.CLASS_NAME, 'leaflet-control-zoom-in')
driver.execute_script("arguments[0].click();", l);
driver.save_screenshot('map.png')
display(Image("map.png"))
# Out:
# C:\Users\tsyck\AppData\Local\Temp/ipykernel_15404/1920834572.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %% [markdown]
# <b>Вывод: </b>все районы, которые включают в себя 2 улицы из первой десятки находятся к Югу от центра, но не на южной окраине города, т.к. именно где-то между центром и окраинами улицы сходятся ближе всего. Основная масса улиц из первой десятки находится на Юге, поэтому и районы с 2-умя такими улицами сосредоточены к Югу от центра.

# %% [markdown]
# #### Улицы с одним заведением

# %% [markdown]
# Рассмотрим теперь количество улиц с одним заведением в районах:

# %%
one_item_areas = streets.loc[streets['amount'] == 1, ['area', 'amount']].groupby('area', as_index=False)\
.agg({'amount':'count'}).sort_values(by='amount', ascending=False)
one_item_areas.head(10)
# Out:
#                    area  amount
# 90      район Хамовники      27
# 24      Таганский район      26
# 3       Басманный район      24
# 25       Тверской район      21
# 19    Пресненский район      18
# 60   район Марьина Роща      17
# 30          район Арбат      17
# 12      Мещанский район      16
# 42  район Замоскворечье      14
# 82     район Сокольники      13

# %% [markdown]
# В первой 10-ке по количеству улиц с одним заведением оказались все районы, находящиеся в центре или приближенные к нему.

# %%
one_item_areas.tail(15)
# Out:
#                         area  amount
# 1         Алтуфьевский район       1
# 43   район Западное Дегунино       1
# 97    район Южное Медведково       1
# 64          район Некрасовка       1
# 63  район Нагатино-Садовники       1
# 94  район Чертаново Северное       1
# 79            район Северный       1
# 84      район Старое Крюково       1
# 29         Ярославский район       1
# 55        район Левобережный       1
# 88      район Филевский Парк       1
# 20         Район Гагаринский       1
# 59             район Марфино       1
# 85            район Строгино       1
# 87         район Теплый Стан       1

# %% [markdown]
# Основная часть районов, где находится всего одна улица с одним заведением, находится ближе к окраинам города.

# %% [markdown]
# Визуализируем полученные данные:

# %%
import folium
from IPython.core.display import display, HTML

# %%
def folium_deepnote_show(m):
    data = m.get_root().render()
    data_fixed_height = data.replace('width: 100%;height: 100%', 'width: 100%').replace('height: 100.0%;', 'height: 609px;', 1)
    display(HTML(data_fixed_height))

# %%
#создаем карту
communities_map = folium.Map(location=[55.7522, 37.6156], zoom_start=9, 
                             tiles='https://{s}.tile.openstreetmap.se/hydda/full/{z}/{x}/{y}.png',
                             attr="Hydda.Full"
                            )
# Добавляем границы райнов и заливку в зависимости от количества улиц
folium.Choropleth(
    geo_data=communities_json,
    data=one_item_areas,
    columns=['area', 'amount'],
    key_on='feature.properties.name',
    bins = 9,
    nan_fill_color = 'white',
    fill_color='YlGnBu', 
    fill_opacity=1, 
    line_opacity=1,
    legend_name='Количество улиц с 1 заведением',
    smooth_factor=0
).add_to(communities_map)

#communities_map
communities_map.save("map.html")

# %%
driver.get(mapUrl)
l = driver.find_element(By.CLASS_NAME, 'leaflet-control-zoom-in')
driver.execute_script("arguments[0].click();", l);
driver.save_screenshot('map.png')
driver.quit()
display(Image("map.png"))

# %% [markdown]
# <b>Вывод: </b>в центральных районах Москвы, вероятнее всего, размещение своего заведения на любой улице рассамтривается эффективным и улицы короче, поэтому там чаще других районов встречаются улицы с одним заведением. В то же время, в районах расположенных дальше от центра в качестве более удачного места рассматриваются большие значимые улицы.

# %% [markdown]
# #### Места в заведениях на популярных улицах

# %% [markdown]
# Рассмотрим количество мест в заведениях улиц из первой десятки:

# %%
top_10_streets_data = rest_data[
    rest_data['street'].isin(
        streets.loc[streets['amount'] >= 101, 'street'].unique()
    )
]
top_10_streets_data.head()
# Out:
#          id      object_name chain                        object_type  \
# 151  155973  кафе «андерсон»    да                               кафе
# 152   23618    кафе «subway»    да                               кафе
# 153  155852   кафе «ламаджо»   нет                               кафе
# 154  152556    шаурма в пите   нет  предприятие быстрого обслуживания
# 155  120658          выпечка   нет                          кафетерий
#
#                                               address  number  \
# 151             город москва, варшавское шоссе, дом 2     150
# 152   город москва, варшавское шоссе, дом 7, корпус 1      36
# 153            город москва, варшавское шоссе, дом 29      30
# 154  город москва, варшавское шоссе, дом 72, корпус 2       0
# 155           город москва, варшавское шоссе, дом 100       2
#
#                street
# 151  варшавское шоссе
# 152  варшавское шоссе
# 153  варшавское шоссе
# 154  варшавское шоссе
# 155  варшавское шоссе

# %%
plt.figure(figsize=(13, 7))
plt.title('Количество мест в заведениях на первых 10 улицах')
ax = sns.boxplot(data = top_10_streets_data, x = 'number', y = 'street', palette="viridis", orient = 'h')
ax.set_xlabel('Количество мест')
ax.set_ylabel('Улицы')
sns.despine()

# %% [markdown]
# <b>Вывод: </b> улицы можно разбить на группы по распределию и медианному количеству.
#
#  - Все проспекты имеют медиану около 40 мест, также у проспектов среднее отклонение от медианы существенно выше, чем у остальных.
#  - Второй группой можно выделить шоссе, улицу и набережную: их медианное количество мест находится ближе к 25 и отклонение ниже.
#  - На Ходынском бульваре в среднем мест меньше всего. Это короткая улица, где большая доля заведений пользуется общими местами.

# %% [markdown]
# ## Выводы:
#
#  - Наибольшую долю всех предприятий занимают кафе, их суммарное число выше двух следующих за ними категорий. На 2-ом и 3-ем местах рестораны и столовые соответственно. Меньше всего закусочных и отделов кулинарии в магазинах.
#  - Основная масса заведений(около 80%) не относятся к сетевым.
#  - Максимальная доля сетевых заведений в предприятиях быстрого обслуживания (41.13%) и отделах кулинарии магазинов (28.57%). Реже всего сетевую к сетям принадлежат столовые, буфеты и бары.
#  - У крупных сетей среднее количество мест обычно не больше 100. Возможна определенная обратная связь между размером сети и количеством мест в ее заведениях.
#  - В среднем, количество мест в столовых и ресторанах существенно выше, чем в остальных типах заведений. При этом, количество мест в столовых распределено относительно равномерно, поэтому доля заведений с количеством мест выше 150 немного ниже 25%.
#  - Закусочные, кафетерии и отделы кулинарии в магазинах стандартно имеют мест меньше остальных.
#  - У закусочных, предприятий быстрого питания и отделов кулинарии сетевые заведения чаще имеют больше мест, по сравнению с не сетевыми.
#  - Улицы с наибольшим количеством объектов общественного питания - длинные проспекты и шоссе в Южной половине города. Такие улицы чаще встречаются в южных районах, находящихся между центральными и окраинными районами.
#  - Улицы, с одним объектом общественного питания чаще всего встречаются в центральных районах Москвы. Вероятно, в остальных районах маленькие улицы реже кажутся удачным местом.
#  - Среди улиц с максимальным числом заведений можно выделить проспекты в отдельную группу: в среднем, заведения на них имеют около 40 мест, но разброс значений большой.
#  - На шоссе, улицах и набережных количество мест чаще около 25.
